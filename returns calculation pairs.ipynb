# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
from statsmodels.tsa.stattools import coint
import seaborn as sns
import winsound
import math
from statistics import mean
import pickle
from tabulate import tabulate

# %%
df = pd.read_csv("Prices.csv")
df.drop(["Name"],axis=1,inplace=True)
df.drop(["PX_VOLUME"],axis=1,inplace=True)
df['date']= pd.to_datetime(df['date'],dayfirst=True)

# %%
pickle_in = open("dict.pickle","rb")
pairs_from_dict = pickle.load(pickle_in)
pairs_from_dict
# Out:
# {Timestamp('2008-01-01 00:00:00'): [['EIM IS Equity', 'RIL IS Equity'],
#   ['EIM IS Equity', 'ITC IS Equity'],
#   ['EIM IS Equity', 'TTAN IS Equity'],
#   ['EIM IS Equity', 'APNT IS Equity'],
#   ['EIM IS Equity', 'HDFC IS Equity'],
#   ['EIM IS Equity', 'BHARTI IS Equity'],
#   ['EIM IS Equity', 'ADSEZ IS Equity'],
#   ['EIM IS Equity', 'TTMT IS Equity'],
#   ['EIM IS Equity', 'UPLL IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['AXSB IS Equity', 'LT IS Equity'],
#   ['AXSB IS Equity', 'ICICIBC IS Equity'],
#   ['AXSB IS Equity', 'ADSEZ IS Equity'],
#   ['AXSB IS Equity', 'GRASIM IS Equity'],
#   ['RIL IS Equity', 'JSTL IS Equity'],
#   ['GAIL IS Equity', 'APNT IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['ITC IS Equity', 'BHARTI IS Equity'],
#   ['ITC IS Equity', 'ADSEZ IS Equity'],
#   ['MM IS Equity', 'RIL IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'HDFC IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['TATA IS Equity', 'TCS IS Equity'],
#   ['Z IS Equity', 'LT IS Equity'],
#   ['TTAN IS Equity', 'BHARTI IS Equity'],
#   ['TTAN IS Equity', 'ADSEZ IS Equity'],
#   ['TTAN IS Equity', 'UPLL IS Equity'],
#   ['HDFCB IS Equity', 'IIB IS Equity'],
#   ['APNT IS Equity', 'WPRO IS Equity'],
#   ['APNT IS Equity', 'TECHM IS Equity'],
#   ['VEDL IS Equity', 'WPRO IS Equity'],
#   ['WPRO IS Equity', 'TCS IS Equity'],
#   ['HMCL IS Equity', 'HUVR IS Equity'],
#   ['HDFC IS Equity', 'LT IS Equity'],
#   ['HDFC IS Equity', 'IIB IS Equity'],
#   ['HDFC IS Equity', 'BHARTI IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'UTCEM IS Equity'],
#   ['KMB IS Equity', 'UTCEM IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['IIB IS Equity', 'ICICIBC IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['PWGR IS Equity', 'AXSB IS Equity'],
#   ['PWGR IS Equity', 'HDFCB IS Equity'],
#   ['PWGR IS Equity', 'APNT IS Equity'],
#   ['PWGR IS Equity', 'HDFC IS Equity'],
#   ['PWGR IS Equity', 'LT IS Equity'],
#   ['PWGR IS Equity', 'BHARTI IS Equity'],
#   ['PWGR IS Equity', 'TTMT IS Equity'],
#   ['PWGR IS Equity', 'UTCEM IS Equity'],
#   ['PWGR IS Equity', 'YES IS Equity'],
#   ['ICICIBC IS Equity', 'YES IS Equity'],
#   ['BHARTI IS Equity', 'RIL IS Equity'],
#   ['BHARTI IS Equity', 'ADSEZ IS Equity'],
#   ['BHARTI IS Equity', 'UTCEM IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'GRASIM IS Equity'],
#   ['ADSEZ IS Equity', 'RIL IS Equity'],
#   ['ADSEZ IS Equity', 'TATA IS Equity'],
#   ['ADSEZ IS Equity', 'HDFCB IS Equity'],
#   ['ADSEZ IS Equity', 'APNT IS Equity'],
#   ['ADSEZ IS Equity', 'JSTL IS Equity'],
#   ['ADSEZ IS Equity', 'WPRO IS Equity'],
#   ['ADSEZ IS Equity', 'HDFC IS Equity'],
#   ['ADSEZ IS Equity', 'LT IS Equity'],
#   ['ADSEZ IS Equity', 'ICICIBC IS Equity'],
#   ['ADSEZ IS Equity', 'TTMT IS Equity'],
#   ['ADSEZ IS Equity', 'UPLL IS Equity'],
#   ['UTCEM IS Equity', 'GRASIM IS Equity'],
#   ['TECHM IS Equity', 'WPRO IS Equity'],
#   ['IOCL IS Equity', 'AXSB IS Equity'],
#   ['IOCL IS Equity', 'SBIN IS Equity'],
#   ['IOCL IS Equity', 'SUNP IS Equity'],
#   ['IOCL IS Equity', 'HDFCB IS Equity'],
#   ['IOCL IS Equity', 'CIPLA IS Equity'],
#   ['IOCL IS Equity', 'APNT IS Equity'],
#   ['IOCL IS Equity', 'VEDL IS Equity'],
#   ['IOCL IS Equity', 'WPRO IS Equity'],
#   ['IOCL IS Equity', 'HMCL IS Equity'],
#   ['IOCL IS Equity', 'HUVR IS Equity'],
#   ['IOCL IS Equity', 'INFO IS Equity'],
#   ['IOCL IS Equity', 'HDFC IS Equity'],
#   ['IOCL IS Equity', 'HCLT IS Equity'],
#   ['IOCL IS Equity', 'ICICIBC IS Equity'],
#   ['IOCL IS Equity', 'TCS IS Equity'],
#   ['IOCL IS Equity', 'UTCEM IS Equity'],
#   ['IOCL IS Equity', 'UPLL IS Equity'],
#   ['IOCL IS Equity', 'YES IS Equity']],
#  Timestamp('2008-02-01 00:00:00'): [['EIM IS Equity', 'ITC IS Equity'],
#   ['EIM IS Equity', 'TATA IS Equity'],
#   ['EIM IS Equity', 'TTAN IS Equity'],
#   ['EIM IS Equity', 'VEDL IS Equity'],
#   ['EIM IS Equity', 'WPRO IS Equity'],
#   ['EIM IS Equity', 'DRRD IS Equity'],
#   ['EIM IS Equity', 'INFO IS Equity'],
#   ['EIM IS Equity', 'TCS IS Equity'],
#   ['EIM IS Equity', 'UPLL IS Equity'],
#   ['EIM IS Equity', 'TECHM IS Equity'],
#   ['AXSB IS Equity', 'HDFC IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['AXSB IS Equity', 'IIB IS Equity'],
#   ['AXSB IS Equity', 'TTMT IS Equity'],
#   ['RIL IS Equity', 'BHARTI IS Equity'],
#   ['GAIL IS Equity', 'HDFCB IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['GAIL IS Equity', 'HDFC IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'HDFC IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['Z IS Equity', 'LT IS Equity'],
#   ['TTAN IS Equity', 'RIL IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'VEDL IS Equity'],
#   ['TTAN IS Equity', 'WPRO IS Equity'],
#   ['TTAN IS Equity', 'INFO IS Equity'],
#   ['TTAN IS Equity', 'BHARTI IS Equity'],
#   ['TTAN IS Equity', 'UPLL IS Equity'],
#   ['TTAN IS Equity', 'TECHM IS Equity'],
#   ['HDFCB IS Equity', 'IIB IS Equity'],
#   ['CIPLA IS Equity', 'SUNP IS Equity'],
#   ['JSTL IS Equity', 'TATA IS Equity'],
#   ['VEDL IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TECHM IS Equity'],
#   ['HMCL IS Equity', 'HUVR IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'LT IS Equity'],
#   ['HDFC IS Equity', 'BHARTI IS Equity'],
#   ['HDFC IS Equity', 'ADSEZ IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['KMB IS Equity', 'RIL IS Equity'],
#   ['KMB IS Equity', 'HNDL IS Equity'],
#   ['KMB IS Equity', 'BHARTI IS Equity'],
#   ['KMB IS Equity', 'TTMT IS Equity'],
#   ['LT IS Equity', 'MM IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['MSIL IS Equity', 'IIB IS Equity'],
#   ['IIB IS Equity', 'ICICIBC IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['PWGR IS Equity', 'GRASIM IS Equity'],
#   ['BHARTI IS Equity', 'EIM IS Equity'],
#   ['BHARTI IS Equity', 'AXSB IS Equity'],
#   ['BHARTI IS Equity', 'GAIL IS Equity'],
#   ['BHARTI IS Equity', 'MM IS Equity'],
#   ['BHARTI IS Equity', 'Z IS Equity'],
#   ['BHARTI IS Equity', 'APNT IS Equity'],
#   ['BHARTI IS Equity', 'IIB IS Equity'],
#   ['BHARTI IS Equity', 'ADSEZ IS Equity'],
#   ['BHARTI IS Equity', 'TCS IS Equity'],
#   ['BHARTI IS Equity', 'TTMT IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'GRASIM IS Equity'],
#   ['BHARTI IS Equity', 'YES IS Equity'],
#   ['ADSEZ IS Equity', 'VEDL IS Equity'],
#   ['ADSEZ IS Equity', 'TCS IS Equity'],
#   ['UTCEM IS Equity', 'GRASIM IS Equity'],
#   ['UPLL IS Equity', 'APNT IS Equity'],
#   ['YES IS Equity', 'UTCEM IS Equity']],
#  Timestamp('2008-03-01 00:00:00'): [['EIM IS Equity', 'ITC IS Equity'],
#   ['EIM IS Equity', 'TATA IS Equity'],
#   ['EIM IS Equity', 'TTAN IS Equity'],
#   ['EIM IS Equity', 'VEDL IS Equity'],
#   ['EIM IS Equity', 'WPRO IS Equity'],
#   ['EIM IS Equity', 'DRRD IS Equity'],
#   ['EIM IS Equity', 'INFO IS Equity'],
#   ['EIM IS Equity', 'ADSEZ IS Equity'],
#   ['EIM IS Equity', 'TCS IS Equity'],
#   ['EIM IS Equity', 'UPLL IS Equity'],
#   ['EIM IS Equity', 'TECHM IS Equity'],
#   ['AXSB IS Equity', 'APNT IS Equity'],
#   ['AXSB IS Equity', 'HDFC IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['AXSB IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'ICICIBC IS Equity'],
#   ['RIL IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'TCS IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['GAIL IS Equity', 'HDFC IS Equity'],
#   ['MM IS Equity', 'HDFC IS Equity'],
#   ['MM IS Equity', 'LT IS Equity'],
#   ['MM IS Equity', 'YES IS Equity'],
#   ['SBIN IS Equity', 'GAIL IS Equity'],
#   ['SBIN IS Equity', 'HDFCB IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['HNDL IS Equity', 'YES IS Equity'],
#   ['TATA IS Equity', 'TCS IS Equity'],
#   ['Z IS Equity', 'LT IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'LT IS Equity'],
#   ['TTAN IS Equity', 'BHARTI IS Equity'],
#   ['TTAN IS Equity', 'UPLL IS Equity'],
#   ['TTAN IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'YES IS Equity'],
#   ['APNT IS Equity', 'HDFC IS Equity'],
#   ['APNT IS Equity', 'LT IS Equity'],
#   ['APNT IS Equity', 'BHARTI IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['JSTL IS Equity', 'TATA IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['JSTL IS Equity', 'DRRD IS Equity'],
#   ['JSTL IS Equity', 'TCS IS Equity'],
#   ['VEDL IS Equity', 'TATA IS Equity'],
#   ['VEDL IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TECHM IS Equity'],
#   ['HUVR IS Equity', 'BPCL IS Equity'],
#   ['HUVR IS Equity', 'HMCL IS Equity'],
#   ['HUVR IS Equity', 'IOCL IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'LT IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'TECHM IS Equity'],
#   ['HDFC IS Equity', 'YES IS Equity'],
#   ['KMB IS Equity', 'APNT IS Equity'],
#   ['KMB IS Equity', 'YES IS Equity'],
#   ['LT IS Equity', 'RIL IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['LT IS Equity', 'TECHM IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['IIB IS Equity', 'ICICIBC IS Equity'],
#   ['ICICIBC IS Equity', 'TCS IS Equity'],
#   ['ICICIBC IS Equity', 'TTMT IS Equity'],
#   ['ICICIBC IS Equity', 'TECHM IS Equity'],
#   ['BHARTI IS Equity', 'EIM IS Equity'],
#   ['BHARTI IS Equity', 'TECHM IS Equity'],
#   ['BHARTI IS Equity', 'YES IS Equity'],
#   ['TCS IS Equity', 'YES IS Equity'],
#   ['TTMT IS Equity', 'YES IS Equity'],
#   ['UTCEM IS Equity', 'GRASIM IS Equity'],
#   ['TECHM IS Equity', 'YES IS Equity'],
#   ['YES IS Equity', 'AXSB IS Equity'],
#   ['YES IS Equity', 'RIL IS Equity'],
#   ['YES IS Equity', 'GAIL IS Equity'],
#   ['YES IS Equity', 'SUNP IS Equity'],
#   ['YES IS Equity', 'ONGC IS Equity'],
#   ['YES IS Equity', 'WPRO IS Equity'],
#   ['YES IS Equity', 'INFO IS Equity'],
#   ['YES IS Equity', 'UPLL IS Equity']],
#  Timestamp('2008-04-01 00:00:00'): [['EIM IS Equity', 'ITC IS Equity'],
#   ['EIM IS Equity', 'HNDL IS Equity'],
#   ['EIM IS Equity', 'TATA IS Equity'],
#   ['EIM IS Equity', 'TTAN IS Equity'],
#   ['EIM IS Equity', 'JSTL IS Equity'],
#   ['EIM IS Equity', 'VEDL IS Equity'],
#   ['EIM IS Equity', 'WPRO IS Equity'],
#   ['EIM IS Equity', 'DRRD IS Equity'],
#   ['EIM IS Equity', 'INFO IS Equity'],
#   ['EIM IS Equity', 'HCLT IS Equity'],
#   ['EIM IS Equity', 'ICICIBC IS Equity'],
#   ['EIM IS Equity', 'ADSEZ IS Equity'],
#   ['EIM IS Equity', 'TCS IS Equity'],
#   ['EIM IS Equity', 'TTMT IS Equity'],
#   ['EIM IS Equity', 'UPLL IS Equity'],
#   ['EIM IS Equity', 'TECHM IS Equity'],
#   ['EIM IS Equity', 'YES IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['AXSB IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'TCS IS Equity'],
#   ['RIL IS Equity', 'TECHM IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['MM IS Equity', 'RIL IS Equity'],
#   ['MM IS Equity', 'UPLL IS Equity'],
#   ['SBIN IS Equity', 'TTAN IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['TATA IS Equity', 'JSTL IS Equity'],
#   ['TATA IS Equity', 'DRRD IS Equity'],
#   ['TATA IS Equity', 'TCS IS Equity'],
#   ['SUNP IS Equity', 'Z IS Equity'],
#   ['SUNP IS Equity', 'APNT IS Equity'],
#   ['SUNP IS Equity', 'LT IS Equity'],
#   ['Z IS Equity', 'TTAN IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['Z IS Equity', 'LT IS Equity'],
#   ['Z IS Equity', 'UPLL IS Equity'],
#   ['Z IS Equity', 'TECHM IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'LT IS Equity'],
#   ['TTAN IS Equity', 'UPLL IS Equity'],
#   ['BPCL IS Equity', 'HUVR IS Equity'],
#   ['APNT IS Equity', 'HDFC IS Equity'],
#   ['APNT IS Equity', 'BHARTI IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['JSTL IS Equity', 'DRRD IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['JSTL IS Equity', 'TCS IS Equity'],
#   ['VEDL IS Equity', 'TATA IS Equity'],
#   ['VEDL IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TCS IS Equity'],
#   ['WPRO IS Equity', 'TECHM IS Equity'],
#   ['HUVR IS Equity', 'IOCL IS Equity'],
#   ['INFO IS Equity', 'TATA IS Equity'],
#   ['INFO IS Equity', 'DRRD IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'LT IS Equity'],
#   ['HDFC IS Equity', 'BHARTI IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'UPLL IS Equity'],
#   ['HDFC IS Equity', 'TECHM IS Equity'],
#   ['HDFC IS Equity', 'YES IS Equity'],
#   ['KMB IS Equity', 'YES IS Equity'],
#   ['LT IS Equity', 'APNT IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['LT IS Equity', 'UPLL IS Equity'],
#   ['LT IS Equity', 'TECHM IS Equity'],
#   ['LT IS Equity', 'YES IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['IIB IS Equity', 'ADSEZ IS Equity'],
#   ['BHARTI IS Equity', 'YES IS Equity'],
#   ['TCS IS Equity', 'TTMT IS Equity'],
#   ['UPLL IS Equity', 'APNT IS Equity'],
#   ['UPLL IS Equity', 'YES IS Equity']],
#  Timestamp('2008-05-01 00:00:00'): [['EIM IS Equity', 'HNDL IS Equity'],
#   ['EIM IS Equity', 'JSTL IS Equity'],
#   ['EIM IS Equity', 'ICICIBC IS Equity'],
#   ['EIM IS Equity', 'ADSEZ IS Equity'],
#   ['EIM IS Equity', 'TTMT IS Equity'],
#   ['AXSB IS Equity', 'SUNP IS Equity'],
#   ['AXSB IS Equity', 'Z IS Equity'],
#   ['AXSB IS Equity', 'APNT IS Equity'],
#   ['RIL IS Equity', 'TCS IS Equity'],
#   ['RIL IS Equity', 'UPLL IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['SBIN IS Equity', 'TTAN IS Equity'],
#   ['HNDL IS Equity', 'TATA IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['TATA IS Equity', 'JSTL IS Equity'],
#   ['SUNP IS Equity', 'APNT IS Equity'],
#   ['SUNP IS Equity', 'LT IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['Z IS Equity', 'LT IS Equity'],
#   ['Z IS Equity', 'BHARTI IS Equity'],
#   ['Z IS Equity', 'TECHM IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['HDFCB IS Equity', 'UPLL IS Equity'],
#   ['APNT IS Equity', 'HDFC IS Equity'],
#   ['APNT IS Equity', 'BHARTI IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['JSTL IS Equity', 'IIB IS Equity'],
#   ['JSTL IS Equity', 'TCS IS Equity'],
#   ['VEDL IS Equity', 'INFO IS Equity'],
#   ['WPRO IS Equity', 'TCS IS Equity'],
#   ['HUVR IS Equity', 'BPCL IS Equity'],
#   ['HUVR IS Equity', 'IOCL IS Equity'],
#   ['HDFC IS Equity', 'Z IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'LT IS Equity'],
#   ['HDFC IS Equity', 'IIB IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'UPLL IS Equity'],
#   ['HDFC IS Equity', 'TECHM IS Equity'],
#   ['KMB IS Equity', 'APNT IS Equity'],
#   ['KMB IS Equity', 'IIB IS Equity'],
#   ['KMB IS Equity', 'TCS IS Equity'],
#   ['KMB IS Equity', 'UPLL IS Equity'],
#   ['KMB IS Equity', 'YES IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['LT IS Equity', 'UPLL IS Equity'],
#   ['LT IS Equity', 'YES IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['IIB IS Equity', 'HNDL IS Equity'],
#   ['IIB IS Equity', 'Z IS Equity'],
#   ['IIB IS Equity', 'BPCL IS Equity'],
#   ['IIB IS Equity', 'APNT IS Equity'],
#   ['IIB IS Equity', 'WPRO IS Equity'],
#   ['IIB IS Equity', 'INFO IS Equity'],
#   ['IIB IS Equity', 'HCLT IS Equity'],
#   ['IIB IS Equity', 'ICICIBC IS Equity'],
#   ['IIB IS Equity', 'ADSEZ IS Equity'],
#   ['IIB IS Equity', 'TCS IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['IIB IS Equity', 'UPLL IS Equity'],
#   ['IIB IS Equity', 'TECHM IS Equity'],
#   ['ICICIBC IS Equity', 'TATA IS Equity'],
#   ['ICICIBC IS Equity', 'JSTL IS Equity'],
#   ['ICICIBC IS Equity', 'ADSEZ IS Equity'],
#   ['ICICIBC IS Equity', 'TCS IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'AXSB IS Equity'],
#   ['BHARTI IS Equity', 'SUNP IS Equity'],
#   ['BHARTI IS Equity', 'HDFC IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'TECHM IS Equity'],
#   ['BHARTI IS Equity', 'YES IS Equity'],
#   ['TCS IS Equity', 'TTMT IS Equity'],
#   ['UPLL IS Equity', 'YES IS Equity']],
#  Timestamp('2008-06-01 00:00:00'): [['EIM IS Equity', 'AXSB IS Equity'],
#   ['EIM IS Equity', 'RIL IS Equity'],
#   ['EIM IS Equity', 'BHARTI IS Equity'],
#   ['EIM IS Equity', 'ADSEZ IS Equity'],
#   ['AXSB IS Equity', 'BHARTI IS Equity'],
#   ['GAIL IS Equity', 'HDFCB IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['ITC IS Equity', 'RIL IS Equity'],
#   ['ITC IS Equity', 'GAIL IS Equity'],
#   ['ITC IS Equity', 'MM IS Equity'],
#   ['ITC IS Equity', 'HNDL IS Equity'],
#   ['ITC IS Equity', 'TATA IS Equity'],
#   ['ITC IS Equity', 'SUNP IS Equity'],
#   ['ITC IS Equity', 'CIPLA IS Equity'],
#   ['ITC IS Equity', 'ONGC IS Equity'],
#   ['ITC IS Equity', 'JSTL IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'WPRO IS Equity'],
#   ['ITC IS Equity', 'DRRD IS Equity'],
#   ['ITC IS Equity', 'INFO IS Equity'],
#   ['ITC IS Equity', 'NTPC IS Equity'],
#   ['ITC IS Equity', 'BHARTI IS Equity'],
#   ['ITC IS Equity', 'TTMT IS Equity'],
#   ['ITC IS Equity', 'UTCEM IS Equity'],
#   ['ITC IS Equity', 'UPLL IS Equity'],
#   ['ITC IS Equity', 'TECHM IS Equity'],
#   ['ITC IS Equity', 'GRASIM IS Equity'],
#   ['MM IS Equity', 'ONGC IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['HNDL IS Equity', 'TECHM IS Equity'],
#   ['TATA IS Equity', 'JSTL IS Equity'],
#   ['SUNP IS Equity', 'AXSB IS Equity'],
#   ['SUNP IS Equity', 'Z IS Equity'],
#   ['SUNP IS Equity', 'APNT IS Equity'],
#   ['SUNP IS Equity', 'LT IS Equity'],
#   ['SUNP IS Equity', 'HCLT IS Equity'],
#   ['SUNP IS Equity', 'TTMT IS Equity'],
#   ['SUNP IS Equity', 'TECHM IS Equity'],
#   ['SUNP IS Equity', 'YES IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['HDFCB IS Equity', 'SBIN IS Equity'],
#   ['HDFCB IS Equity', 'ONGC IS Equity'],
#   ['CIPLA IS Equity', 'UTCEM IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['JSTL IS Equity', 'HNDL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['JSTL IS Equity', 'TCS IS Equity'],
#   ['INFO IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'ONGC IS Equity'],
#   ['HDFC IS Equity', 'IIB IS Equity'],
#   ['LT IS Equity', 'UPLL IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['HCLT IS Equity', 'Z IS Equity'],
#   ['ICICIBC IS Equity', 'ADSEZ IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'ONGC IS Equity'],
#   ['BHARTI IS Equity', 'KMB IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['ADSEZ IS Equity', 'MM IS Equity'],
#   ['ADSEZ IS Equity', 'ONGC IS Equity'],
#   ['ADSEZ IS Equity', 'VEDL IS Equity'],
#   ['ADSEZ IS Equity', 'LT IS Equity'],
#   ['ADSEZ IS Equity', 'IIB IS Equity'],
#   ['ADSEZ IS Equity', 'UPLL IS Equity'],
#   ['TCS IS Equity', 'WPRO IS Equity'],
#   ['TCS IS Equity', 'TTMT IS Equity'],
#   ['UPLL IS Equity', 'ONGC IS Equity'],
#   ['UPLL IS Equity', 'YES IS Equity']],
#  Timestamp('2008-07-01 00:00:00'): [['RIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['GAIL IS Equity', 'GRASIM IS Equity'],
#   ['ITC IS Equity', 'EIM IS Equity'],
#   ['ITC IS Equity', 'RIL IS Equity'],
#   ['ITC IS Equity', 'GAIL IS Equity'],
#   ['ITC IS Equity', 'MM IS Equity'],
#   ['ITC IS Equity', 'SBIN IS Equity'],
#   ['ITC IS Equity', 'HDFCB IS Equity'],
#   ['ITC IS Equity', 'CIPLA IS Equity'],
#   ['ITC IS Equity', 'ONGC IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'WPRO IS Equity'],
#   ['ITC IS Equity', 'DRRD IS Equity'],
#   ['ITC IS Equity', 'INFO IS Equity'],
#   ['ITC IS Equity', 'LT IS Equity'],
#   ['ITC IS Equity', 'MSIL IS Equity'],
#   ['ITC IS Equity', 'NTPC IS Equity'],
#   ['ITC IS Equity', 'IIB IS Equity'],
#   ['ITC IS Equity', 'PWGR IS Equity'],
#   ['ITC IS Equity', 'BHARTI IS Equity'],
#   ['ITC IS Equity', 'ADSEZ IS Equity'],
#   ['ITC IS Equity', 'TTMT IS Equity'],
#   ['ITC IS Equity', 'UTCEM IS Equity'],
#   ['ITC IS Equity', 'UPLL IS Equity'],
#   ['ITC IS Equity', 'GRASIM IS Equity'],
#   ['ITC IS Equity', 'IOCL IS Equity'],
#   ['MM IS Equity', 'INFO IS Equity'],
#   ['SBIN IS Equity', 'AXSB IS Equity'],
#   ['SBIN IS Equity', 'HDFCB IS Equity'],
#   ['HNDL IS Equity', 'TATA IS Equity'],
#   ['SUNP IS Equity', 'Z IS Equity'],
#   ['SUNP IS Equity', 'HCLT IS Equity'],
#   ['SUNP IS Equity', 'TTMT IS Equity'],
#   ['Z IS Equity', 'HCLT IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'IIB IS Equity'],
#   ['CIPLA IS Equity', 'UTCEM IS Equity'],
#   ['CIPLA IS Equity', 'GRASIM IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['ONGC IS Equity', 'INFO IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'TCS IS Equity'],
#   ['VEDL IS Equity', 'INFO IS Equity'],
#   ['WPRO IS Equity', 'HDFC IS Equity'],
#   ['WPRO IS Equity', 'BHARTI IS Equity'],
#   ['WPRO IS Equity', 'UPLL IS Equity'],
#   ['HUVR IS Equity', 'EIM IS Equity'],
#   ['INFO IS Equity', 'HDFC IS Equity'],
#   ['INFO IS Equity', 'ADSEZ IS Equity'],
#   ['HDFC IS Equity', 'ONGC IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['HCLT IS Equity', 'TTAN IS Equity'],
#   ['HCLT IS Equity', 'APNT IS Equity'],
#   ['PWGR IS Equity', 'UTCEM IS Equity'],
#   ['ICICIBC IS Equity', 'ADSEZ IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'AXSB IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['TCS IS Equity', 'TTMT IS Equity']],
#  Timestamp('2008-08-01 00:00:00'): [['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'GRASIM IS Equity'],
#   ['MM IS Equity', 'INFO IS Equity'],
#   ['SBIN IS Equity', 'AXSB IS Equity'],
#   ['SBIN IS Equity', 'HDFCB IS Equity'],
#   ['SBIN IS Equity', 'LT IS Equity'],
#   ['HNDL IS Equity', 'TATA IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['TATA IS Equity', 'Z IS Equity'],
#   ['TATA IS Equity', 'ONGC IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['CIPLA IS Equity', 'VEDL IS Equity'],
#   ['CIPLA IS Equity', 'GRASIM IS Equity'],
#   ['APNT IS Equity', 'HCLT IS Equity'],
#   ['ONGC IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'MM IS Equity'],
#   ['JSTL IS Equity', 'LT IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'HDFC IS Equity'],
#   ['WPRO IS Equity', 'UPLL IS Equity'],
#   ['INFO IS Equity', 'VEDL IS Equity'],
#   ['HDFC IS Equity', 'AXSB IS Equity'],
#   ['HDFC IS Equity', 'TECHM IS Equity'],
#   ['HDFC IS Equity', 'YES IS Equity'],
#   ['KMB IS Equity', 'HDFC IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'AXSB IS Equity'],
#   ['BHARTI IS Equity', 'KMB IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['ADSEZ IS Equity', 'GAIL IS Equity'],
#   ['UPLL IS Equity', 'HDFCB IS Equity'],
#   ['UPLL IS Equity', 'TTMT IS Equity'],
#   ['GRASIM IS Equity', 'UTCEM IS Equity'],
#   ['YES IS Equity', 'APNT IS Equity']],
#  Timestamp('2008-09-01 00:00:00'): [['AXSB IS Equity', 'SBIN IS Equity'],
#   ['AXSB IS Equity', 'HDFC IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'ONGC IS Equity'],
#   ['GAIL IS Equity', 'JSTL IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'GRASIM IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'INFO IS Equity'],
#   ['ITC IS Equity', 'MSIL IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'INFO IS Equity'],
#   ['SBIN IS Equity', 'HDFCB IS Equity'],
#   ['SBIN IS Equity', 'JSTL IS Equity'],
#   ['SBIN IS Equity', 'HDFC IS Equity'],
#   ['SBIN IS Equity', 'KMB IS Equity'],
#   ['SBIN IS Equity', 'LT IS Equity'],
#   ['SBIN IS Equity', 'ICICIBC IS Equity'],
#   ['SBIN IS Equity', 'UPLL IS Equity'],
#   ['HNDL IS Equity', 'AXSB IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['TATA IS Equity', 'AXSB IS Equity'],
#   ['TATA IS Equity', 'GAIL IS Equity'],
#   ['TATA IS Equity', 'SBIN IS Equity'],
#   ['TATA IS Equity', 'LT IS Equity'],
#   ['TATA IS Equity', 'MSIL IS Equity'],
#   ['TATA IS Equity', 'UPLL IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'HDFC IS Equity'],
#   ['TTAN IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['HDFCB IS Equity', 'LT IS Equity'],
#   ['HDFCB IS Equity', 'UPLL IS Equity'],
#   ['BPCL IS Equity', 'EIM IS Equity'],
#   ['BPCL IS Equity', 'VEDL IS Equity'],
#   ['CIPLA IS Equity', 'VEDL IS Equity'],
#   ['CIPLA IS Equity', 'GRASIM IS Equity'],
#   ['APNT IS Equity', 'HCLT IS Equity'],
#   ['ONGC IS Equity', 'JSTL IS Equity'],
#   ['ONGC IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'AXSB IS Equity'],
#   ['JSTL IS Equity', 'MM IS Equity'],
#   ['JSTL IS Equity', 'HDFC IS Equity'],
#   ['JSTL IS Equity', 'LT IS Equity'],
#   ['JSTL IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'YES IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['INFO IS Equity', 'MSIL IS Equity'],
#   ['HDFC IS Equity', 'GAIL IS Equity'],
#   ['KMB IS Equity', 'UPLL IS Equity'],
#   ['PWGR IS Equity', 'UTCEM IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'SBIN IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['ADSEZ IS Equity', 'SBIN IS Equity'],
#   ['UPLL IS Equity', 'GAIL IS Equity'],
#   ['UPLL IS Equity', 'LT IS Equity'],
#   ['YES IS Equity', 'AXSB IS Equity'],
#   ['YES IS Equity', 'APNT IS Equity']],
#  Timestamp('2008-10-01 00:00:00'): [['AXSB IS Equity', 'Z IS Equity'],
#   ['AXSB IS Equity', 'HDFC IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'VEDL IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['GAIL IS Equity', 'HMCL IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'MSIL IS Equity'],
#   ['GAIL IS Equity', 'GRASIM IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'MSIL IS Equity'],
#   ['MM IS Equity', 'TATA IS Equity'],
#   ['MM IS Equity', 'ONGC IS Equity'],
#   ['MM IS Equity', 'JSTL IS Equity'],
#   ['SBIN IS Equity', 'Z IS Equity'],
#   ['SBIN IS Equity', 'HDFC IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'AXSB IS Equity'],
#   ['TATA IS Equity', 'ONGC IS Equity'],
#   ['TATA IS Equity', 'JSTL IS Equity'],
#   ['TATA IS Equity', 'VEDL IS Equity'],
#   ['TATA IS Equity', 'DRRD IS Equity'],
#   ['TATA IS Equity', 'KMB IS Equity'],
#   ['TATA IS Equity', 'LT IS Equity'],
#   ['TATA IS Equity', 'IIB IS Equity'],
#   ['TATA IS Equity', 'ICICIBC IS Equity'],
#   ['TATA IS Equity', 'UPLL IS Equity'],
#   ['TATA IS Equity', 'IOCL IS Equity'],
#   ['SUNP IS Equity', 'AXSB IS Equity'],
#   ['SUNP IS Equity', 'RIL IS Equity'],
#   ['SUNP IS Equity', 'MM IS Equity'],
#   ['SUNP IS Equity', 'SBIN IS Equity'],
#   ['SUNP IS Equity', 'HDFCB IS Equity'],
#   ['SUNP IS Equity', 'HDFC IS Equity'],
#   ['SUNP IS Equity', 'KMB IS Equity'],
#   ['SUNP IS Equity', 'ICICIBC IS Equity'],
#   ['SUNP IS Equity', 'BHARTI IS Equity'],
#   ['SUNP IS Equity', 'ADSEZ IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['Z IS Equity', 'WPRO IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'HDFC IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'HCLT IS Equity'],
#   ['Z IS Equity', 'ICICIBC IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['TTAN IS Equity', 'APNT IS Equity'],
#   ['TTAN IS Equity', 'IIB IS Equity'],
#   ['HDFCB IS Equity', 'TATA IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['HDFCB IS Equity', 'UPLL IS Equity'],
#   ['CIPLA IS Equity', 'HMCL IS Equity'],
#   ['CIPLA IS Equity', 'GRASIM IS Equity'],
#   ['ONGC IS Equity', 'HMCL IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['JSTL IS Equity', 'HDFC IS Equity'],
#   ['JSTL IS Equity', 'ICICIBC IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'TTMT IS Equity'],
#   ['DRRD IS Equity', 'HNDL IS Equity'],
#   ['HMCL IS Equity', 'UTCEM IS Equity'],
#   ['HMCL IS Equity', 'UPLL IS Equity'],
#   ['HMCL IS Equity', 'GRASIM IS Equity'],
#   ['INFO IS Equity', 'MSIL IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'IIB IS Equity'],
#   ['HDFC IS Equity', 'YES IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['IIB IS Equity', 'TECHM IS Equity'],
#   ['IIB IS Equity', 'YES IS Equity'],
#   ['ICICIBC IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'UPLL IS Equity'],
#   ['UPLL IS Equity', 'ONGC IS Equity'],
#   ['UPLL IS Equity', 'JSTL IS Equity'],
#   ['UPLL IS Equity', 'VEDL IS Equity'],
#   ['UPLL IS Equity', 'HDFC IS Equity'],
#   ['UPLL IS Equity', 'KMB IS Equity'],
#   ['UPLL IS Equity', 'LT IS Equity'],
#   ['UPLL IS Equity', 'GRASIM IS Equity']],
#  Timestamp('2008-11-01 00:00:00'): [['AXSB IS Equity', 'HDFC IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['GAIL IS Equity', 'HMCL IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'HDFC IS Equity'],
#   ['GAIL IS Equity', 'MSIL IS Equity'],
#   ['ITC IS Equity', 'APNT IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'CIPLA IS Equity'],
#   ['MM IS Equity', 'ONGC IS Equity'],
#   ['MM IS Equity', 'JSTL IS Equity'],
#   ['SBIN IS Equity', 'Z IS Equity'],
#   ['SBIN IS Equity', 'DRRD IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'GAIL IS Equity'],
#   ['TATA IS Equity', 'JSTL IS Equity'],
#   ['TATA IS Equity', 'DRRD IS Equity'],
#   ['TATA IS Equity', 'HDFC IS Equity'],
#   ['TATA IS Equity', 'ICICIBC IS Equity'],
#   ['SUNP IS Equity', 'RIL IS Equity'],
#   ['SUNP IS Equity', 'SBIN IS Equity'],
#   ['SUNP IS Equity', 'HDFCB IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'IOCL IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'TATA IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['BPCL IS Equity', 'EIM IS Equity'],
#   ['BPCL IS Equity', 'Z IS Equity'],
#   ['BPCL IS Equity', 'INFO IS Equity'],
#   ['BPCL IS Equity', 'HCLT IS Equity'],
#   ['BPCL IS Equity', 'TTMT IS Equity'],
#   ['CIPLA IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['JSTL IS Equity', 'HDFC IS Equity'],
#   ['VEDL IS Equity', 'WPRO IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'TTMT IS Equity'],
#   ['DRRD IS Equity', 'IIB IS Equity'],
#   ['DRRD IS Equity', 'YES IS Equity'],
#   ['HMCL IS Equity', 'HDFC IS Equity'],
#   ['HMCL IS Equity', 'UTCEM IS Equity'],
#   ['INFO IS Equity', 'MSIL IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'IIB IS Equity'],
#   ['HDFC IS Equity', 'ICICIBC IS Equity'],
#   ['NTPC IS Equity', 'RIL IS Equity'],
#   ['NTPC IS Equity', 'ADSEZ IS Equity'],
#   ['NTPC IS Equity', 'UTCEM IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['PWGR IS Equity', 'RIL IS Equity'],
#   ['ICICIBC IS Equity', 'JSTL IS Equity'],
#   ['IOCL IS Equity', 'HDFC IS Equity'],
#   ['IOCL IS Equity', 'IIB IS Equity']],
#  Timestamp('2008-12-01 00:00:00'): [['AXSB IS Equity', 'TATA IS Equity'],
#   ['AXSB IS Equity', 'HDFC IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['RIL IS Equity', 'NTPC IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'JSTL IS Equity'],
#   ['ITC IS Equity', 'APNT IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'GAIL IS Equity'],
#   ['MM IS Equity', 'CIPLA IS Equity'],
#   ['SBIN IS Equity', 'Z IS Equity'],
#   ['SBIN IS Equity', 'DRRD IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'HDFCB IS Equity'],
#   ['TATA IS Equity', 'HDFC IS Equity'],
#   ['TATA IS Equity', 'KMB IS Equity'],
#   ['TATA IS Equity', 'ICICIBC IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['BPCL IS Equity', 'INFO IS Equity'],
#   ['BPCL IS Equity', 'HCLT IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['ONGC IS Equity', 'NTPC IS Equity'],
#   ['ONGC IS Equity', 'UTCEM IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['JSTL IS Equity', 'HDFC IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'TTMT IS Equity'],
#   ['DRRD IS Equity', 'YES IS Equity'],
#   ['HMCL IS Equity', 'UTCEM IS Equity'],
#   ['INFO IS Equity', 'MSIL IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'ICICIBC IS Equity'],
#   ['KMB IS Equity', 'NTPC IS Equity'],
#   ['NTPC IS Equity', 'AXSB IS Equity'],
#   ['NTPC IS Equity', 'GAIL IS Equity'],
#   ['NTPC IS Equity', 'MM IS Equity'],
#   ['NTPC IS Equity', 'SBIN IS Equity'],
#   ['NTPC IS Equity', 'HNDL IS Equity'],
#   ['NTPC IS Equity', 'TATA IS Equity'],
#   ['NTPC IS Equity', 'SUNP IS Equity'],
#   ['NTPC IS Equity', 'TTAN IS Equity'],
#   ['NTPC IS Equity', 'HDFCB IS Equity'],
#   ['NTPC IS Equity', 'BPCL IS Equity'],
#   ['NTPC IS Equity', 'APNT IS Equity'],
#   ['NTPC IS Equity', 'JSTL IS Equity'],
#   ['NTPC IS Equity', 'WPRO IS Equity'],
#   ['NTPC IS Equity', 'HMCL IS Equity'],
#   ['NTPC IS Equity', 'INFO IS Equity'],
#   ['NTPC IS Equity', 'HDFC IS Equity'],
#   ['NTPC IS Equity', 'LT IS Equity'],
#   ['NTPC IS Equity', 'MSIL IS Equity'],
#   ['NTPC IS Equity', 'ICICIBC IS Equity'],
#   ['NTPC IS Equity', 'ADSEZ IS Equity'],
#   ['NTPC IS Equity', 'UTCEM IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['NTPC IS Equity', 'TECHM IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['IIB IS Equity', 'DRRD IS Equity']],
#  Timestamp('2009-01-01 00:00:00'): [['AXSB IS Equity', 'HDFC IS Equity'],
#   ['AXSB IS Equity', 'KMB IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['ITC IS Equity', 'APNT IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'TATA IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'JSTL IS Equity'],
#   ['SBIN IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'AXSB IS Equity'],
#   ['Z IS Equity', 'APNT IS Equity'],
#   ['Z IS Equity', 'JSTL IS Equity'],
#   ['Z IS Equity', 'WPRO IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'INFO IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['HDFCB IS Equity', 'HDFC IS Equity'],
#   ['BPCL IS Equity', 'INFO IS Equity'],
#   ['BPCL IS Equity', 'HCLT IS Equity'],
#   ['APNT IS Equity', 'IIB IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['ONGC IS Equity', 'HMCL IS Equity'],
#   ['ONGC IS Equity', 'KMB IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['DRRD IS Equity', 'SBIN IS Equity'],
#   ['DRRD IS Equity', 'HNDL IS Equity'],
#   ['DRRD IS Equity', 'IIB IS Equity'],
#   ['DRRD IS Equity', 'YES IS Equity'],
#   ['HMCL IS Equity', 'HDFC IS Equity'],
#   ['HMCL IS Equity', 'LT IS Equity'],
#   ['HMCL IS Equity', 'NTPC IS Equity'],
#   ['HMCL IS Equity', 'UTCEM IS Equity'],
#   ['HDFC IS Equity', 'TTAN IS Equity'],
#   ['HDFC IS Equity', 'KMB IS Equity'],
#   ['HDFC IS Equity', 'ICICIBC IS Equity'],
#   ['KMB IS Equity', 'NTPC IS Equity'],
#   ['NTPC IS Equity', 'MM IS Equity'],
#   ['NTPC IS Equity', 'TATA IS Equity'],
#   ['NTPC IS Equity', 'ONGC IS Equity'],
#   ['NTPC IS Equity', 'UTCEM IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['IOCL IS Equity', 'TTAN IS Equity']],
#  Timestamp('2009-02-01 00:00:00'): [['AXSB IS Equity', 'KMB IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'JSTL IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'IIB IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'TATA IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'Z IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'IIB IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'AXSB IS Equity'],
#   ['TATA IS Equity', 'NTPC IS Equity'],
#   ['Z IS Equity', 'JSTL IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['BPCL IS Equity', 'WPRO IS Equity'],
#   ['BPCL IS Equity', 'INFO IS Equity'],
#   ['BPCL IS Equity', 'HCLT IS Equity'],
#   ['APNT IS Equity', 'YES IS Equity'],
#   ['ONGC IS Equity', 'HMCL IS Equity'],
#   ['ONGC IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'KMB IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'DRRD IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['DRRD IS Equity', 'IIB IS Equity'],
#   ['DRRD IS Equity', 'YES IS Equity'],
#   ['HMCL IS Equity', 'AXSB IS Equity'],
#   ['HMCL IS Equity', 'HDFC IS Equity'],
#   ['HMCL IS Equity', 'LT IS Equity'],
#   ['INFO IS Equity', 'IIB IS Equity'],
#   ['INFO IS Equity', 'HCLT IS Equity'],
#   ['KMB IS Equity', 'NTPC IS Equity'],
#   ['NTPC IS Equity', 'AXSB IS Equity'],
#   ['NTPC IS Equity', 'SUNP IS Equity'],
#   ['NTPC IS Equity', 'TTAN IS Equity'],
#   ['NTPC IS Equity', 'ONGC IS Equity'],
#   ['NTPC IS Equity', 'UTCEM IS Equity'],
#   ['HCLT IS Equity', 'EIM IS Equity'],
#   ['PWGR IS Equity', 'UPLL IS Equity'],
#   ['UTCEM IS Equity', 'TTAN IS Equity'],
#   ['TECHM IS Equity', 'TTAN IS Equity']],
#  Timestamp('2009-03-01 00:00:00'): [['EIM IS Equity', 'HCLT IS Equity'],
#   ['AXSB IS Equity', 'HMCL IS Equity'],
#   ['RIL IS Equity', 'NTPC IS Equity'],
#   ['GAIL IS Equity', 'EIM IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'Z IS Equity'],
#   ['GAIL IS Equity', 'BPCL IS Equity'],
#   ['GAIL IS Equity', 'APNT IS Equity'],
#   ['GAIL IS Equity', 'JSTL IS Equity'],
#   ['GAIL IS Equity', 'VEDL IS Equity'],
#   ['GAIL IS Equity', 'WPRO IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'TATA IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'DRRD IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'IIB IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'Z IS Equity'],
#   ['Z IS Equity', 'JSTL IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['TTAN IS Equity', 'UTCEM IS Equity'],
#   ['BPCL IS Equity', 'WPRO IS Equity'],
#   ['BPCL IS Equity', 'INFO IS Equity'],
#   ['BPCL IS Equity', 'HCLT IS Equity'],
#   ['CIPLA IS Equity', 'VEDL IS Equity'],
#   ['APNT IS Equity', 'IIB IS Equity'],
#   ['ONGC IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'KMB IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['ONGC IS Equity', 'IOCL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'APNT IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'HCLT IS Equity'],
#   ['DRRD IS Equity', 'HNDL IS Equity'],
#   ['DRRD IS Equity', 'IIB IS Equity'],
#   ['DRRD IS Equity', 'YES IS Equity'],
#   ['HMCL IS Equity', 'TECHM IS Equity'],
#   ['HMCL IS Equity', 'IOCL IS Equity'],
#   ['INFO IS Equity', 'IIB IS Equity'],
#   ['INFO IS Equity', 'HCLT IS Equity'],
#   ['HDFC IS Equity', 'ICICIBC IS Equity'],
#   ['HDFC IS Equity', 'IOCL IS Equity'],
#   ['KMB IS Equity', 'IOCL IS Equity'],
#   ['NTPC IS Equity', 'AXSB IS Equity'],
#   ['NTPC IS Equity', 'HDFCB IS Equity'],
#   ['NTPC IS Equity', 'HMCL IS Equity'],
#   ['NTPC IS Equity', 'HCLT IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['ICICIBC IS Equity', 'IOCL IS Equity']],
#  Timestamp('2009-04-01 00:00:00'): [['EIM IS Equity', 'GAIL IS Equity'],
#   ['EIM IS Equity', 'Z IS Equity'],
#   ['EIM IS Equity', 'WPRO IS Equity'],
#   ['EIM IS Equity', 'HCLT IS Equity'],
#   ['AXSB IS Equity', 'HNDL IS Equity'],
#   ['AXSB IS Equity', 'TATA IS Equity'],
#   ['AXSB IS Equity', 'INFO IS Equity'],
#   ['AXSB IS Equity', 'IIB IS Equity'],
#   ['AXSB IS Equity', 'TCS IS Equity'],
#   ['RIL IS Equity', 'EIM IS Equity'],
#   ['RIL IS Equity', 'SBIN IS Equity'],
#   ['RIL IS Equity', 'HNDL IS Equity'],
#   ['RIL IS Equity', 'TATA IS Equity'],
#   ['RIL IS Equity', 'Z IS Equity'],
#   ['RIL IS Equity', 'BPCL IS Equity'],
#   ['RIL IS Equity', 'VEDL IS Equity'],
#   ['RIL IS Equity', 'KMB IS Equity'],
#   ['RIL IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'TTMT IS Equity'],
#   ['RIL IS Equity', 'UPLL IS Equity'],
#   ['RIL IS Equity', 'IOCL IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'Z IS Equity'],
#   ['GAIL IS Equity', 'WPRO IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'TCS IS Equity'],
#   ['MM IS Equity', 'EIM IS Equity'],
#   ['MM IS Equity', 'TATA IS Equity'],
#   ['MM IS Equity', 'Z IS Equity'],
#   ['MM IS Equity', 'DRRD IS Equity'],
#   ['MM IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['TATA IS Equity', 'Z IS Equity'],
#   ['TATA IS Equity', 'WPRO IS Equity'],
#   ['TATA IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'TCS IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['APNT IS Equity', 'JSTL IS Equity'],
#   ['APNT IS Equity', 'IIB IS Equity'],
#   ['APNT IS Equity', 'TCS IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['WPRO IS Equity', 'INFO IS Equity'],
#   ['WPRO IS Equity', 'TTMT IS Equity'],
#   ['DRRD IS Equity', 'IIB IS Equity'],
#   ['KMB IS Equity', 'BPCL IS Equity'],
#   ['KMB IS Equity', 'IOCL IS Equity'],
#   ['NTPC IS Equity', 'BPCL IS Equity'],
#   ['NTPC IS Equity', 'KMB IS Equity'],
#   ['NTPC IS Equity', 'IIB IS Equity'],
#   ['NTPC IS Equity', 'HCLT IS Equity'],
#   ['NTPC IS Equity', 'UPLL IS Equity'],
#   ['NTPC IS Equity', 'TECHM IS Equity'],
#   ['HCLT IS Equity', 'INFO IS Equity']],
#  Timestamp('2009-05-01 00:00:00'): [['EIM IS Equity', 'Z IS Equity'],
#   ['AXSB IS Equity', 'IIB IS Equity'],
#   ['RIL IS Equity', 'TATA IS Equity'],
#   ['RIL IS Equity', 'SUNP IS Equity'],
#   ['RIL IS Equity', 'HUVR IS Equity'],
#   ['RIL IS Equity', 'NTPC IS Equity'],
#   ['RIL IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'IOCL IS Equity'],
#   ['GAIL IS Equity', 'EIM IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'Z IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'WPRO IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'BHARTI IS Equity'],
#   ['GAIL IS Equity', 'TCS IS Equity'],
#   ['GAIL IS Equity', 'TTMT IS Equity'],
#   ['MM IS Equity', 'CIPLA IS Equity'],
#   ['MM IS Equity', 'WPRO IS Equity'],
#   ['MM IS Equity', 'DRRD IS Equity'],
#   ['MM IS Equity', 'TCS IS Equity'],
#   ['HNDL IS Equity', 'TATA IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'TTMT IS Equity'],
#   ['TATA IS Equity', 'AXSB IS Equity'],
#   ['TATA IS Equity', 'SUNP IS Equity'],
#   ['TATA IS Equity', 'Z IS Equity'],
#   ['TATA IS Equity', 'WPRO IS Equity'],
#   ['TATA IS Equity', 'DRRD IS Equity'],
#   ['TATA IS Equity', 'INFO IS Equity'],
#   ['TATA IS Equity', 'IIB IS Equity'],
#   ['TATA IS Equity', 'HCLT IS Equity'],
#   ['TATA IS Equity', 'YES IS Equity'],
#   ['SUNP IS Equity', 'BHARTI IS Equity'],
#   ['Z IS Equity', 'HNDL IS Equity'],
#   ['Z IS Equity', 'INFO IS Equity'],
#   ['Z IS Equity', 'IIB IS Equity'],
#   ['Z IS Equity', 'BHARTI IS Equity'],
#   ['Z IS Equity', 'TTMT IS Equity'],
#   ['Z IS Equity', 'YES IS Equity'],
#   ['CIPLA IS Equity', 'DRRD IS Equity'],
#   ['APNT IS Equity', 'JSTL IS Equity'],
#   ['APNT IS Equity', 'IIB IS Equity'],
#   ['JSTL IS Equity', 'VEDL IS Equity'],
#   ['VEDL IS Equity', 'DRRD IS Equity'],
#   ['DRRD IS Equity', 'BHARTI IS Equity'],
#   ['HDFC IS Equity', 'ICICIBC IS Equity'],
#   ['KMB IS Equity', 'MM IS Equity'],
#   ['KMB IS Equity', 'BPCL IS Equity'],
#   ['KMB IS Equity', 'HCLT IS Equity'],
#   ['KMB IS Equity', 'TECHM IS Equity'],
#   ['KMB IS Equity', 'IOCL IS Equity'],
#   ['LT IS Equity', 'ITC IS Equity'],
#   ['LT IS Equity', 'SUNP IS Equity'],
#   ['LT IS Equity', 'BHARTI IS Equity'],
#   ['NTPC IS Equity', 'EIM IS Equity'],
#   ['NTPC IS Equity', 'AXSB IS Equity'],
#   ['NTPC IS Equity', 'GAIL IS Equity'],
#   ['NTPC IS Equity', 'SUNP IS Equity'],
#   ['NTPC IS Equity', 'Z IS Equity'],
#   ['NTPC IS Equity', 'TTAN IS Equity'],
#   ['NTPC IS Equity', 'HDFCB IS Equity'],
#   ['NTPC IS Equity', 'BPCL IS Equity'],
#   ['NTPC IS Equity', 'CIPLA IS Equity'],
#   ['NTPC IS Equity', 'APNT IS Equity'],
#   ['NTPC IS Equity', 'VEDL IS Equity'],
#   ['NTPC IS Equity', 'WPRO IS Equity'],
#   ['NTPC IS Equity', 'DRRD IS Equity'],
#   ['NTPC IS Equity', 'HUVR IS Equity'],
#   ['NTPC IS Equity', 'INFO IS Equity'],
#   ['NTPC IS Equity', 'KMB IS Equity'],
#   ['NTPC IS Equity', 'MSIL IS Equity'],
#   ['NTPC IS Equity', 'IIB IS Equity'],
#   ['NTPC IS Equity', 'HCLT IS Equity'],
#   ['NTPC IS Equity', 'BHARTI IS Equity'],
#   ['NTPC IS Equity', 'TCS IS Equity'],
#   ['NTPC IS Equity', 'TTMT IS Equity'],
#   ['NTPC IS Equity', 'TECHM IS Equity'],
#   ['NTPC IS Equity', 'IOCL IS Equity'],
#   ['NTPC IS Equity', 'YES IS Equity'],
#   ['PWGR IS Equity', 'EIM IS Equity'],
#   ['PWGR IS Equity', 'AXSB IS Equity'],
#   ['PWGR IS Equity', 'GAIL IS Equity'],
#   ['PWGR IS Equity', 'ITC IS Equity'],
#   ['PWGR IS Equity', 'HNDL IS Equity'],
#   ['PWGR IS Equity', 'SUNP IS Equity'],
#   ['PWGR IS Equity', 'Z IS Equity'],
#   ['PWGR IS Equity', 'HDFCB IS Equity'],
#   ['PWGR IS Equity', 'BPCL IS Equity'],
#   ['PWGR IS Equity', 'CIPLA IS Equity'],
#   ['PWGR IS Equity', 'APNT IS Equity'],
#   ['PWGR IS Equity', 'JSTL IS Equity'],
#   ['PWGR IS Equity', 'VEDL IS Equity'],
#   ['PWGR IS Equity', 'WPRO IS Equity'],
#   ['PWGR IS Equity', 'DRRD IS Equity'],
#   ['PWGR IS Equity', 'HMCL IS Equity'],
#   ['PWGR IS Equity', 'INFO IS Equity'],
#   ['PWGR IS Equity', 'MSIL IS Equity'],
#   ['PWGR IS Equity', 'IIB IS Equity'],
#   ['PWGR IS Equity', 'HCLT IS Equity'],
#   ['PWGR IS Equity', 'BHARTI IS Equity'],
#   ['PWGR IS Equity', 'TCS IS Equity'],
#   ['PWGR IS Equity', 'TTMT IS Equity'],
#   ['PWGR IS Equity', 'UPLL IS Equity'],
#   ['PWGR IS Equity', 'YES IS Equity'],
#   ['ICICIBC IS Equity', 'EIM IS Equity'],
#   ['ICICIBC IS Equity', 'ITC IS Equity'],
#   ['ICICIBC IS Equity', 'Z IS Equity'],
#   ['ICICIBC IS Equity', 'BHARTI IS Equity'],
#   ['BHARTI IS Equity', 'APNT IS Equity'],
#   ['BHARTI IS Equity', 'VEDL IS Equity'],
#   ['BHARTI IS Equity', 'YES IS Equity'],
#   ['UPLL IS Equity', 'ONGC IS Equity']],
#  Timestamp('2009-06-01 00:00:00'): [['AXSB IS Equity', 'IIB IS Equity'],
#   ['RIL IS Equity', 'EIM IS Equity'],
#   ['RIL IS Equity', 'AXSB IS Equity'],
#   ['RIL IS Equity', 'GAIL IS Equity'],
#   ['RIL IS Equity', 'ITC IS Equity'],
#   ['RIL IS Equity', 'MM IS Equity'],
#   ['RIL IS Equity', 'SBIN IS Equity'],
#   ['RIL IS Equity', 'HNDL IS Equity'],
#   ['RIL IS Equity', 'TATA IS Equity'],
#   ['RIL IS Equity', 'SUNP IS Equity'],
#   ['RIL IS Equity', 'Z IS Equity'],
#   ['RIL IS Equity', 'HDFCB IS Equity'],
#   ['RIL IS Equity', 'BPCL IS Equity'],
#   ['RIL IS Equity', 'CIPLA IS Equity'],
#   ['RIL IS Equity', 'APNT IS Equity'],
#   ['RIL IS Equity', 'JSTL IS Equity'],
#   ['RIL IS Equity', 'VEDL IS Equity'],
#   ['RIL IS Equity', 'WPRO IS Equity'],
#   ['RIL IS Equity', 'DRRD IS Equity'],
#   ['RIL IS Equity', 'HMCL IS Equity'],
#   ['RIL IS Equity', 'INFO IS Equity'],
#   ['RIL IS Equity', 'HDFC IS Equity'],
#   ['RIL IS Equity', 'KMB IS Equity'],
#   ['RIL IS Equity', 'LT IS Equity'],
#   ['RIL IS Equity', 'MSIL IS Equity'],
#   ['RIL IS Equity', 'IIB IS Equity'],
#   ['RIL IS Equity', 'HCLT IS Equity'],
#   ['RIL IS Equity', 'ICICIBC IS Equity'],
#   ['RIL IS Equity', 'BHARTI IS Equity'],
#   ['RIL IS Equity', 'TCS IS Equity'],
#   ['RIL IS Equity', 'TTMT IS Equity'],
#   ['RIL IS Equity', 'UTCEM IS Equity'],
#   ['RIL IS Equity', 'TECHM IS Equity'],
#   ['RIL IS Equity', 'IOCL IS Equity'],
#   ['RIL IS Equity', 'YES IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'DRRD IS Equity'],
#   ['MM IS Equity', 'CIPLA IS Equity'],
# ...
#   ['ITC IS Equity', 'HDFCB IS Equity'],
#   ['ITC IS Equity', 'BPCL IS Equity'],
#   ['ITC IS Equity', 'CIPLA IS Equity'],
#   ['ITC IS Equity', 'APNT IS Equity'],
#   ['ITC IS Equity', 'ONGC IS Equity'],
#   ['ITC IS Equity', 'JSTL IS Equity'],
#   ['ITC IS Equity', 'VEDL IS Equity'],
#   ['ITC IS Equity', 'WPRO IS Equity'],
#   ['ITC IS Equity', 'DRRD IS Equity'],
#   ['ITC IS Equity', 'HMCL IS Equity'],
#   ['ITC IS Equity', 'HUVR IS Equity'],
#   ['ITC IS Equity', 'INFO IS Equity'],
#   ['ITC IS Equity', 'HDFC IS Equity'],
#   ['ITC IS Equity', 'KMB IS Equity'],
#   ['ITC IS Equity', 'LT IS Equity'],
#   ['ITC IS Equity', 'MSIL IS Equity'],
#   ['ITC IS Equity', 'NTPC IS Equity'],
#   ['ITC IS Equity', 'IIB IS Equity'],
#   ['ITC IS Equity', 'HCLT IS Equity'],
#   ['ITC IS Equity', 'PWGR IS Equity'],
#   ['ITC IS Equity', 'ICICIBC IS Equity'],
#   ['ITC IS Equity', 'BHARTI IS Equity'],
#   ['ITC IS Equity', 'ADSEZ IS Equity'],
#   ['ITC IS Equity', 'TCS IS Equity'],
#   ['ITC IS Equity', 'TTMT IS Equity'],
#   ['ITC IS Equity', 'UTCEM IS Equity'],
#   ['ITC IS Equity', 'UPLL IS Equity'],
#   ['ITC IS Equity', 'TECHM IS Equity'],
#   ['ITC IS Equity', 'GRASIM IS Equity'],
#   ['ITC IS Equity', 'IOCL IS Equity'],
#   ['ITC IS Equity', 'YES IS Equity'],
#   ['Z IS Equity', 'TTAN IS Equity'],
#   ['Z IS Equity', 'MSIL IS Equity'],
#   ['HDFCB IS Equity', 'HUVR IS Equity'],
#   ['HDFCB IS Equity', 'TCS IS Equity'],
#   ['JSTL IS Equity', 'TECHM IS Equity'],
#   ['WPRO IS Equity', 'VEDL IS Equity'],
#   ['WPRO IS Equity', 'GRASIM IS Equity'],
#   ['DRRD IS Equity', 'BPCL IS Equity'],
#   ['HMCL IS Equity', 'UPLL IS Equity'],
#   ['HDFC IS Equity', 'BPCL IS Equity'],
#   ['HDFC IS Equity', 'JSTL IS Equity'],
#   ['HDFC IS Equity', 'INFO IS Equity'],
#   ['HDFC IS Equity', 'TCS IS Equity'],
#   ['HDFC IS Equity', 'TTMT IS Equity'],
#   ['HDFC IS Equity', 'TECHM IS Equity'],
#   ['IIB IS Equity', 'BPCL IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['ADSEZ IS Equity', 'UTCEM IS Equity']],
#  Timestamp('2017-08-01 00:00:00'): [['MM IS Equity', 'HUVR IS Equity'],
#   ['TATA IS Equity', 'WPRO IS Equity'],
#   ['TATA IS Equity', 'TTMT IS Equity'],
#   ['SUNP IS Equity', 'GAIL IS Equity'],
#   ['HDFCB IS Equity', 'HUVR IS Equity'],
#   ['HDFCB IS Equity', 'TCS IS Equity'],
#   ['JSTL IS Equity', 'BPCL IS Equity'],
#   ['JSTL IS Equity', 'TECHM IS Equity'],
#   ['JSTL IS Equity', 'IOCL IS Equity'],
#   ['WPRO IS Equity', 'UTCEM IS Equity'],
#   ['HMCL IS Equity', 'RIL IS Equity'],
#   ['HMCL IS Equity', 'GAIL IS Equity'],
#   ['HMCL IS Equity', 'PWGR IS Equity'],
#   ['HMCL IS Equity', 'UPLL IS Equity'],
#   ['HDFC IS Equity', 'BPCL IS Equity'],
#   ['NTPC IS Equity', 'HDFC IS Equity'],
#   ['ADSEZ IS Equity', 'UTCEM IS Equity'],
#   ['TTMT IS Equity', 'NTPC IS Equity'],
#   ['TTMT IS Equity', 'GRASIM IS Equity'],
#   ['UPLL IS Equity', 'RIL IS Equity'],
#   ['UPLL IS Equity', 'HDFCB IS Equity'],
#   ['UPLL IS Equity', 'INFO IS Equity'],
#   ['UPLL IS Equity', 'IOCL IS Equity'],
#   ['TECHM IS Equity', 'IOCL IS Equity'],
#   ['IOCL IS Equity', 'BPCL IS Equity'],
#   ['IOCL IS Equity', 'HUVR IS Equity'],
#   ['IOCL IS Equity', 'IIB IS Equity']],
#  Timestamp('2017-09-01 00:00:00'): [['EIM IS Equity', 'PWGR IS Equity'],
#   ['RIL IS Equity', 'ITC IS Equity'],
#   ['GAIL IS Equity', 'AXSB IS Equity'],
#   ['MM IS Equity', 'HUVR IS Equity'],
#   ['BPCL IS Equity', 'IIB IS Equity'],
#   ['JSTL IS Equity', 'TECHM IS Equity'],
#   ['WPRO IS Equity', 'UTCEM IS Equity'],
#   ['HMCL IS Equity', 'RIL IS Equity'],
#   ['HDFC IS Equity', 'BPCL IS Equity'],
#   ['HDFC IS Equity', 'INFO IS Equity'],
#   ['HDFC IS Equity', 'TCS IS Equity'],
#   ['ADSEZ IS Equity', 'HNDL IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2017-10-01 00:00:00'): [['RIL IS Equity', 'HMCL IS Equity'],
#   ['GAIL IS Equity', 'AXSB IS Equity'],
#   ['ITC IS Equity', 'RIL IS Equity'],
#   ['MM IS Equity', 'HUVR IS Equity'],
#   ['TATA IS Equity', 'GRASIM IS Equity'],
#   ['HDFCB IS Equity', 'HUVR IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['BPCL IS Equity', 'TECHM IS Equity'],
#   ['NTPC IS Equity', 'HDFCB IS Equity'],
#   ['GRASIM IS Equity', 'TTMT IS Equity']],
#  Timestamp('2017-11-01 00:00:00'): [['GAIL IS Equity', 'SUNP IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['ITC IS Equity', 'RIL IS Equity'],
#   ['HNDL IS Equity', 'TATA IS Equity'],
#   ['SUNP IS Equity', 'CIPLA IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['TTAN IS Equity', 'EIM IS Equity'],
#   ['TTAN IS Equity', 'SUNP IS Equity'],
#   ['TTAN IS Equity', 'Z IS Equity'],
#   ['TTAN IS Equity', 'CIPLA IS Equity'],
#   ['TTAN IS Equity', 'WPRO IS Equity'],
#   ['TTAN IS Equity', 'DRRD IS Equity'],
#   ['TTAN IS Equity', 'HMCL IS Equity'],
#   ['TTAN IS Equity', 'HDFC IS Equity'],
#   ['TTAN IS Equity', 'LT IS Equity'],
#   ['TTAN IS Equity', 'IIB IS Equity'],
#   ['TTAN IS Equity', 'PWGR IS Equity'],
#   ['TTAN IS Equity', 'ICICIBC IS Equity'],
#   ['TTAN IS Equity', 'ADSEZ IS Equity'],
#   ['TTAN IS Equity', 'UPLL IS Equity'],
#   ['TTAN IS Equity', 'YES IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['BPCL IS Equity', 'TTMT IS Equity'],
#   ['ONGC IS Equity', 'VEDL IS Equity'],
#   ['ONGC IS Equity', 'UPLL IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['JSTL IS Equity', 'TTMT IS Equity'],
#   ['TECHM IS Equity', 'JSTL IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2017-12-01 00:00:00'): [['GAIL IS Equity', 'SBIN IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['ITC IS Equity', 'RIL IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['BPCL IS Equity', 'TTMT IS Equity'],
#   ['BPCL IS Equity', 'IOCL IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['LT IS Equity', 'SUNP IS Equity'],
#   ['BHARTI IS Equity', 'BPCL IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2018-01-01 00:00:00'): [['GAIL IS Equity', 'ITC IS Equity'],
#   ['GAIL IS Equity', 'SBIN IS Equity'],
#   ['GAIL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'ONGC IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['HDFCB IS Equity', 'APNT IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['INFO IS Equity', 'RIL IS Equity'],
#   ['LT IS Equity', 'UPLL IS Equity'],
#   ['BHARTI IS Equity', 'BPCL IS Equity'],
#   ['BHARTI IS Equity', 'TTMT IS Equity'],
#   ['BHARTI IS Equity', 'GRASIM IS Equity'],
#   ['BHARTI IS Equity', 'IOCL IS Equity'],
#   ['TTMT IS Equity', 'GRASIM IS Equity'],
#   ['TECHM IS Equity', 'IOCL IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2018-02-01 00:00:00'): [['RIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'ITC IS Equity'],
#   ['GAIL IS Equity', 'TCS IS Equity'],
#   ['HNDL IS Equity', 'HDFCB IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'ONGC IS Equity'],
#   ['HNDL IS Equity', 'HDFC IS Equity'],
#   ['HNDL IS Equity', 'NTPC IS Equity'],
#   ['TATA IS Equity', 'ONGC IS Equity'],
#   ['Z IS Equity', 'AXSB IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['HDFCB IS Equity', 'APNT IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['CIPLA IS Equity', 'SUNP IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['VEDL IS Equity', 'HUVR IS Equity'],
#   ['HDFC IS Equity', 'APNT IS Equity'],
#   ['ICICIBC IS Equity', 'WPRO IS Equity'],
#   ['BHARTI IS Equity', 'TTMT IS Equity'],
#   ['TECHM IS Equity', 'IOCL IS Equity'],
#   ['IOCL IS Equity', 'AXSB IS Equity'],
#   ['IOCL IS Equity', 'ICICIBC IS Equity'],
#   ['IOCL IS Equity', 'BHARTI IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2018-03-01 00:00:00'): [['RIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'ITC IS Equity'],
#   ['TATA IS Equity', 'NTPC IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['HDFCB IS Equity', 'APNT IS Equity'],
#   ['ONGC IS Equity', 'NTPC IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['BHARTI IS Equity', 'BPCL IS Equity'],
#   ['BHARTI IS Equity', 'TTMT IS Equity'],
#   ['BHARTI IS Equity', 'IOCL IS Equity'],
#   ['GRASIM IS Equity', 'EIM IS Equity'],
#   ['IOCL IS Equity', 'Z IS Equity'],
#   ['IOCL IS Equity', 'DRRD IS Equity'],
#   ['IOCL IS Equity', 'TTMT IS Equity']],
#  Timestamp('2018-04-01 00:00:00'): [['EIM IS Equity', 'TTMT IS Equity'],
#   ['GAIL IS Equity', 'ITC IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['HNDL IS Equity', 'HDFCB IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['Z IS Equity', 'EIM IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['ONGC IS Equity', 'NTPC IS Equity'],
#   ['ONGC IS Equity', 'GRASIM IS Equity'],
#   ['IOCL IS Equity', 'IIB IS Equity'],
#   ['IOCL IS Equity', 'YES IS Equity']],
#  Timestamp('2018-05-01 00:00:00'): [['GAIL IS Equity', 'ITC IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'NTPC IS Equity'],
#   ['GAIL IS Equity', 'UTCEM IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['TATA IS Equity', 'ONGC IS Equity'],
#   ['Z IS Equity', 'EIM IS Equity'],
#   ['Z IS Equity', 'WPRO IS Equity'],
#   ['Z IS Equity', 'DRRD IS Equity'],
#   ['Z IS Equity', 'HMCL IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['APNT IS Equity', 'HDFC IS Equity'],
#   ['ONGC IS Equity', 'NTPC IS Equity'],
#   ['WPRO IS Equity', 'ICICIBC IS Equity'],
#   ['IIB IS Equity', 'BHARTI IS Equity'],
#   ['BHARTI IS Equity', 'TTMT IS Equity'],
#   ['BHARTI IS Equity', 'IOCL IS Equity'],
#   ['TCS IS Equity', 'HCLT IS Equity']],
#  Timestamp('2018-06-01 00:00:00'): [['EIM IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'TATA IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['GAIL IS Equity', 'CIPLA IS Equity'],
#   ['GAIL IS Equity', 'JSTL IS Equity'],
#   ['GAIL IS Equity', 'NTPC IS Equity'],
#   ['GAIL IS Equity', 'GRASIM IS Equity'],
#   ['HNDL IS Equity', 'TTAN IS Equity'],
#   ['HNDL IS Equity', 'HDFCB IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['TATA IS Equity', 'SUNP IS Equity'],
#   ['Z IS Equity', 'WPRO IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['WPRO IS Equity', 'ICICIBC IS Equity'],
#   ['DRRD IS Equity', 'WPRO IS Equity'],
#   ['INFO IS Equity', 'RIL IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['HCLT IS Equity', 'TCS IS Equity'],
#   ['BHARTI IS Equity', 'IOCL IS Equity'],
#   ['ADSEZ IS Equity', 'HDFC IS Equity']],
#  Timestamp('2018-07-01 00:00:00'): [['EIM IS Equity', 'MM IS Equity'],
#   ['RIL IS Equity', 'INFO IS Equity'],
#   ['GAIL IS Equity', 'EIM IS Equity'],
#   ['GAIL IS Equity', 'MM IS Equity'],
#   ['GAIL IS Equity', 'TATA IS Equity'],
#   ['GAIL IS Equity', 'SUNP IS Equity'],
#   ['GAIL IS Equity', 'Z IS Equity'],
#   ['GAIL IS Equity', 'VEDL IS Equity'],
#   ['GAIL IS Equity', 'WPRO IS Equity'],
#   ['GAIL IS Equity', 'IIB IS Equity'],
#   ['GAIL IS Equity', 'TTMT IS Equity'],
#   ['GAIL IS Equity', 'YES IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['TATA IS Equity', 'SUNP IS Equity'],
#   ['Z IS Equity', 'WPRO IS Equity'],
#   ['BPCL IS Equity', 'BHARTI IS Equity'],
#   ['BPCL IS Equity', 'ADSEZ IS Equity'],
#   ['WPRO IS Equity', 'ICICIBC IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['ADSEZ IS Equity', 'HDFC IS Equity'],
#   ['IOCL IS Equity', 'BHARTI IS Equity']],
#  Timestamp('2018-08-01 00:00:00'): [['EIM IS Equity', 'MM IS Equity'],
#   ['AXSB IS Equity', 'HNDL IS Equity'],
#   ['AXSB IS Equity', 'HDFCB IS Equity'],
#   ['ITC IS Equity', 'TTMT IS Equity'],
#   ['SBIN IS Equity', 'HDFC IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['HNDL IS Equity', 'WPRO IS Equity'],
#   ['HNDL IS Equity', 'ICICIBC IS Equity'],
#   ['HNDL IS Equity', 'UPLL IS Equity'],
#   ['SUNP IS Equity', 'JSTL IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['HDFCB IS Equity', 'ICICIBC IS Equity'],
#   ['BPCL IS Equity', 'AXSB IS Equity'],
#   ['BPCL IS Equity', 'RIL IS Equity'],
#   ['BPCL IS Equity', 'ADSEZ IS Equity'],
#   ['DRRD IS Equity', 'HNDL IS Equity'],
#   ['DRRD IS Equity', 'APNT IS Equity'],
#   ['DRRD IS Equity', 'VEDL IS Equity'],
#   ['DRRD IS Equity', 'UPLL IS Equity'],
#   ['IIB IS Equity', 'ITC IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['ICICIBC IS Equity', 'KMB IS Equity'],
#   ['ADSEZ IS Equity', 'SBIN IS Equity'],
#   ['ADSEZ IS Equity', 'HDFC IS Equity'],
#   ['UPLL IS Equity', 'TTAN IS Equity']],
#  Timestamp('2018-09-01 00:00:00'): [['EIM IS Equity', 'MM IS Equity'],
#   ['EIM IS Equity', 'VEDL IS Equity'],
#   ['MM IS Equity', 'HNDL IS Equity'],
#   ['MM IS Equity', 'VEDL IS Equity'],
#   ['HNDL IS Equity', 'APNT IS Equity'],
#   ['HNDL IS Equity', 'JSTL IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['SUNP IS Equity', 'HUVR IS Equity'],
#   ['Z IS Equity', 'HDFC IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['Z IS Equity', 'ICICIBC IS Equity'],
#   ['Z IS Equity', 'BHARTI IS Equity'],
#   ['Z IS Equity', 'TCS IS Equity'],
#   ['BPCL IS Equity', 'AXSB IS Equity'],
#   ['BPCL IS Equity', 'UPLL IS Equity'],
#   ['WPRO IS Equity', 'AXSB IS Equity'],
#   ['WPRO IS Equity', 'UPLL IS Equity'],
#   ['MSIL IS Equity', 'INFO IS Equity'],
#   ['IIB IS Equity', 'GAIL IS Equity'],
#   ['IIB IS Equity', 'ITC IS Equity'],
#   ['IIB IS Equity', 'HUVR IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['BHARTI IS Equity', 'TCS IS Equity'],
#   ['ADSEZ IS Equity', 'SBIN IS Equity']],
#  Timestamp('2018-10-01 00:00:00'): [['EIM IS Equity', 'GAIL IS Equity'],
#   ['EIM IS Equity', 'MM IS Equity'],
#   ['EIM IS Equity', 'INFO IS Equity'],
#   ['EIM IS Equity', 'TCS IS Equity'],
#   ['AXSB IS Equity', 'RIL IS Equity'],
#   ['RIL IS Equity', 'UPLL IS Equity'],
#   ['ITC IS Equity', 'TTMT IS Equity'],
#   ['MM IS Equity', 'VEDL IS Equity'],
#   ['MM IS Equity', 'INFO IS Equity'],
#   ['MM IS Equity', 'BHARTI IS Equity'],
#   ['MM IS Equity', 'TCS IS Equity'],
#   ['HNDL IS Equity', 'MM IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['HNDL IS Equity', 'INFO IS Equity'],
#   ['HNDL IS Equity', 'KMB IS Equity'],
#   ['HNDL IS Equity', 'BHARTI IS Equity'],
#   ['HNDL IS Equity', 'TCS IS Equity'],
#   ['SUNP IS Equity', 'BPCL IS Equity'],
#   ['SUNP IS Equity', 'HUVR IS Equity'],
#   ['SUNP IS Equity', 'TCS IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['Z IS Equity', 'BHARTI IS Equity'],
#   ['TTAN IS Equity', 'HDFCB IS Equity'],
#   ['CIPLA IS Equity', 'APNT IS Equity'],
#   ['CIPLA IS Equity', 'HUVR IS Equity'],
#   ['JSTL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'INFO IS Equity'],
#   ['VEDL IS Equity', 'BHARTI IS Equity'],
#   ['VEDL IS Equity', 'TCS IS Equity'],
#   ['DRRD IS Equity', 'RIL IS Equity'],
#   ['KMB IS Equity', 'BHARTI IS Equity'],
#   ['IIB IS Equity', 'GAIL IS Equity'],
#   ['IIB IS Equity', 'ITC IS Equity'],
#   ['IIB IS Equity', 'TTMT IS Equity'],
#   ['IIB IS Equity', 'YES IS Equity'],
#   ['PWGR IS Equity', 'YES IS Equity'],
#   ['ICICIBC IS Equity', 'Z IS Equity'],
#   ['ICICIBC IS Equity', 'HDFCB IS Equity'],
#   ['ICICIBC IS Equity', 'KMB IS Equity'],
#   ['ICICIBC IS Equity', 'BHARTI IS Equity'],
#   ['ICICIBC IS Equity', 'TCS IS Equity'],
#   ['TCS IS Equity', 'Z IS Equity'],
#   ['TCS IS Equity', 'JSTL IS Equity'],
#   ['TCS IS Equity', 'KMB IS Equity'],
#   ['TCS IS Equity', 'BHARTI IS Equity'],
#   ['UPLL IS Equity', 'IOCL IS Equity'],
#   ['IOCL IS Equity', 'AXSB IS Equity']],
#  Timestamp('2018-11-01 00:00:00'): [['EIM IS Equity', 'INFO IS Equity'],
#   ['AXSB IS Equity', 'UPLL IS Equity'],
#   ['MM IS Equity', 'VEDL IS Equity'],
#   ['HNDL IS Equity', 'VEDL IS Equity'],
#   ['SUNP IS Equity', 'ITC IS Equity'],
#   ['SUNP IS Equity', 'Z IS Equity'],
#   ['SUNP IS Equity', 'IIB IS Equity'],
#   ['SUNP IS Equity', 'PWGR IS Equity'],
#   ['Z IS Equity', 'KMB IS Equity'],
#   ['Z IS Equity', 'ICICIBC IS Equity'],
#   ['TTAN IS Equity', 'HDFCB IS Equity'],
#   ['CIPLA IS Equity', 'WPRO IS Equity'],
#   ['JSTL IS Equity', 'GAIL IS Equity'],
#   ['INFO IS Equity', 'MM IS Equity'],
#   ['INFO IS Equity', 'MSIL IS Equity'],
#   ['KMB IS Equity', 'BHARTI IS Equity'],
#   ['IIB IS Equity', 'GAIL IS Equity'],
#   ['IIB IS Equity', 'ITC IS Equity'],
#   ['IIB IS Equity', 'TATA IS Equity'],
#   ['ICICIBC IS Equity', 'BHARTI IS Equity'],
#   ['BHARTI IS Equity', 'Z IS Equity'],
#   ['TCS IS Equity', 'BHARTI IS Equity']]}

# %% [markdown]
# Making date list having month's starting date starting from 2008 Jan to 2019 Nov

# %%
start_date=pd.date_range('2008-01-01','2019-11-30', freq='MS').strftime("%Y-%b-%d").tolist()
df['date']= pd.to_datetime(df['date'],dayfirst=True)
start_date = pd.to_datetime(start_date,dayfirst=True)

# %% [markdown]
# Function for calculating returns given a pair, start and end date of the trading period. Also the return over the invested amount.

# %%
def returns (pair, st_date,end_date,amount):
    y=amount
    df1=df.copy()
    df1 = df1[df1['Ticker']==pair[0]]
    df1 = df1[df1['date']>=st_date]
    df1 = df1[df1['date']<end_date]
    df2=df.copy()
    df2 = df2[df2['Ticker']==pair[1]]
    df2 = df2[df2['date']>=st_date]
    df2 = df2[df2['date']<end_date]
    date = df1['date'].tolist()
    pr1 = df1['PX_LAST'].tolist()
    pr2 = df2['PX_LAST'].tolist()

    main_df = pd.DataFrame(
        {'date': date,
         pair[0]: pr1,
         pair[1]: pr2})
    
    ratio = []
    for i in range(len(main_df)):
        ratio.append(math.log(main_df.iloc[i][pair[1]]/main_df.iloc[i][pair[0]]))
    main_df['ln']=ratio
    
    
    mvg_avg=[]
    std_dev=[]
    for i in range(len(main_df)):
        window=[]
        if i<10:
            mvg_avg.append(0)
        #mvg_avg.append(0)
            std_dev.append(0)
        #std_dev.append(0)
        else:
            for j in range(0,10):
                window.append(main_df.iloc[i-j-1]['ln'])
            #last10.append(df2.iloc[i-j-1]['ratio'])
            mvg_avg.append(mean(window))
        #mvg_avg.append(mean(last10))
            std_dev.append(np.std(window))
        #std_dev.append(np.std(last10))

    main_df['mvg_avg']=mvg_avg
    main_df['std_dev']=std_dev
    
    z_score=[]
    #z_score=[]
    for i in range(len(main_df)):
        if i<10:
            z_score.append(0)
#        z_score.append(0)
        else:
            z_score.append((main_df.iloc[i]['ln']-main_df.iloc[i]['mvg_avg'])/main_df.iloc[i]['std_dev'])
#        z_score.append((df2.iloc[i]['ratio']-df2.iloc[i]['mvg_avg'])/df2.iloc[i]['std_dev'])
    main_df['z_score']=z_score
    
    buy_threshold=-2
    sell_threshold=2
    SL=4
    TP=0
    
    signal=[]
#signal=[]

    for i in range(len(main_df)):
        if (main_df.iloc[i]['z_score']<buy_threshold and abs(main_df.iloc[i]['z_score'])<SL):
            signal.append('BUY')
        elif (main_df.iloc[i]['z_score']>sell_threshold and abs(main_df.iloc[i]['z_score'])<SL):
            signal.append('SELL')
        else:
            signal.append('')
    main_df['signal']=signal
    
    
    status=['']*len(main_df)
    for i in range (len(main_df)):
        #print (i)
        if status[i-1]=='' or status[i-1]=='SL' or status[i-1]=='TP':
            status[i]= main_df.iloc[i]['signal']
            #print (status[i])
        elif abs(z_score[i])> SL:
            if status[i-1]=='BUY' or status[i-1]=='SELL':
                status[i]= 'SL'
                #print (status[i])
        elif z_score[i-1]/z_score[i]<0:
            if status[i-1]=='BUY' or status[i-1]=='SELL':
                status[i]= 'TP'
                #print (status[i])
        else:
            status[i]=status[i-1]
            #print (status[i])
            
    main_df['status']=status
    pos1_open=0
    pos1_close=0
    pos2_open=0
    pos2_close=0
    position=0
    profit=[]
    pos1_pnl=0
    pos2_pnl=0
            
    for i in range (len(main_df)):
        
        if pos1_open==0:
            #print(i)
            #print (pos1_open)
            if status[i]=='BUY':
                pos1_open=main_df.iloc[i][pair[1]]
                pos2_open=main_df.iloc[i][pair[0]]
                position = 1
                #print (pos1_open)
            if status[i]=='SELL':
                pos1_open=main_df.iloc[i][pair[1]]
                pos2_open=main_df.iloc[i][pair[0]]
                position = -1
                #print (pos1_open)
        if status[i]=='SL' or status[i]=='TP':
            #print (i)
            pos1_close= main_df.iloc[i][pair[1]]
            pos2_close= main_df.iloc[i][pair[0]]
            if position ==-1:
                pos1_pnl=(pos1_open-pos1_close)*100/pos1_open
                pos2_pnl=(pos2_close-pos2_open)*100/pos2_open
            if position ==1:
                pos2_pnl=(pos2_open-pos2_close)*100/pos2_open
                pos1_pnl=(pos1_close-pos1_open)*100/pos1_open
            pos1_open=0
            pos1_close=0
            pos2_open=0
            pos2_close=0
            position=0
            profit.append(pos1_pnl+pos2_pnl)
    #print (position)
    #print (pos1_open)
    #print (pos1_close)
    #print (pos2_open)
    #print (pos2_close)
    if position!=0:
        main_df.at[len(main_df)-1, 'status']='Square Off'
        pos1_close=main_df.iloc[len(main_df)-1][pair[1]]
        pos2_close=main_df.iloc[len(main_df)-1][pair[0]]
        if position==1:
            pos2_pnl=(pos2_open-pos2_close)*100/pos2_open
            pos1_pnl=(pos1_close-pos1_open)*100/pos1_open
        if position ==-1:
            pos1_pnl=(pos1_open-pos1_close)*100/pos1_open
            pos2_pnl=(pos2_close-pos2_open)*100/pos2_open
        #print (pos1_close)
        #print (pos2_close)
        pos1_open=0
        pos1_close=0
        pos2_open=0
        pos2_close=0
        position=0
        profit.append(pos1_pnl+pos2_pnl)
        
        
    for i in range (len(profit)):
        y = y*(1+profit[i]/100)
        #print (y)
    return sum(profit), profit, main_df, y

# %%
st_date = datetime.datetime(2019, 2, 1)
end_date = datetime.datetime(2019, 5, 1)
invested_amount = 1000
pair = ['RIL IS Equity', 'INFO IS Equity']
net_profit, profit_by_trades, history, amount=returns(pair, st_date,end_date,invested_amount)
trading_sheet = history.copy()
trading_sheet.drop(['ln','mvg_avg','std_dev'],inplace=True,axis=1)
trading_sheet.set_index('date',inplace=True)
#trading_sheet

# %% [markdown]
# Printing the individual pairs trade results

# %%
print('The pair involves\033[1m',pair[0],'\033[0mand\033[1m',pair[1],'\033[0mover the trading period\033[1m',st_date,'\033[0m to \033[1m',end_date,'\033[0m')
print('The net profit over the trading period is\033[1m',round(net_profit,ndigits=2),'%\033[0m')
print('If\033[1m',round(invested_amount,ndigits=2),'\033[0mINR is invested over the trading period (with compounding), it finally amounts to\033[1m',round(amount,ndigits=2),'\033[0m INR')
print('The respective profit on each individual position is\033[1m',list(np.around(np.array(profit_by_trades),2)),'\033[0m in %')
print('The trading sheet over the period is:-')
print(tabulate(trading_sheet, headers='keys', tablefmt='psql'))
# Out:
# The pair involves RIL IS Equity and INFO IS Equity over the trading period 2019-02-01 00:00:00  to  2019-05-01 00:00:00
# The net profit over the trading period is 5.41 %
# If 1000 INR is invested over the trading period (with compounding), it finally amounts to 1052.47  INR
# The respective profit on each individual position is [4.1, -4.64, 1.66, 4.29]  in %
# The trading sheet over the period is:-
# +---------------------+-----------------+------------------+-------------+----------+----------+
# | date                |   RIL IS Equity |   INFO IS Equity |     z_score | signal   | status   |
# |---------------------+-----------------+------------------+-------------+----------+----------|
# | 2019-02-01 00:00:00 |         1249.95 |           757.05 |  0          |          |          |
# | 2019-02-04 00:00:00 |         1290.9  |           755.9  |  0          |          |          |
# | 2019-02-05 00:00:00 |         1291.55 |           754.85 |  0          |          |          |
# | 2019-02-06 00:00:00 |         1310.25 |           763.3  |  0          |          |          |
# | 2019-02-07 00:00:00 |         1290.4  |           764    |  0          |          |          |
# | 2019-02-08 00:00:00 |         1277.7  |           760.9  |  0          |          |          |
# | 2019-02-11 00:00:00 |         1253.25 |           762.8  |  0          |          |          |
# | 2019-02-12 00:00:00 |         1256.4  |           750.45 |  0          |          |          |
# | 2019-02-13 00:00:00 |         1245.95 |           754.9  |  0          |          |          |
# | 2019-02-14 00:00:00 |         1224.2  |           740.05 |  0          |          |          |
# | 2019-02-15 00:00:00 |         1244.45 |           741.95 |  0.00657487 |          |          |
# | 2019-02-18 00:00:00 |         1220.1  |           741.05 |  1.37589    |          |          |
# | 2019-02-19 00:00:00 |         1216.1  |           724.3  | -0.204514   |          |          |
# | 2019-02-20 00:00:00 |         1234.35 |           740.7  |  0.201219   |          |          |
# | 2019-02-21 00:00:00 |         1246.9  |           733.45 | -2.20193    | BUY      | BUY      |
# | 2019-02-22 00:00:00 |         1232.35 |           734.95 | -0.569213   |          | BUY      |
# | 2019-02-25 00:00:00 |         1232.3  |           754.9  |  2.02871    | SELL     | TP       |
# | 2019-02-26 00:00:00 |         1220.25 |           742.5  |  1.18879    |          |          |
# | 2019-02-27 00:00:00 |         1223.5  |           735.25 | -0.0775317  |          |          |
# | 2019-02-28 00:00:00 |         1231.05 |           734.3  | -0.653059   |          |          |
# | 2019-03-01 00:00:00 |         1226.05 |           741.9  |  0.705823   |          |          |
# | 2019-03-05 00:00:00 |         1237.65 |           732.5  | -1.33871    |          |          |
# | 2019-03-06 00:00:00 |         1264.8  |           732.5  | -2.92099    | BUY      | BUY      |
# | 2019-03-07 00:00:00 |         1270.25 |           722.95 | -3.12671    | BUY      | BUY      |
# | 2019-03-08 00:00:00 |         1267.1  |           712.35 | -2.61912    | BUY      | BUY      |
# | 2019-03-11 00:00:00 |         1304.1  |           711.25 | -3.00647    | BUY      | BUY      |
# | 2019-03-12 00:00:00 |         1331.35 |           706.95 | -2.73557    | BUY      | BUY      |
# | 2019-03-13 00:00:00 |         1347.3  |           708.45 | -2.1653     | BUY      | BUY      |
# | 2019-03-14 00:00:00 |         1341.55 |           708.35 | -1.57096    |          | BUY      |
# | 2019-03-15 00:00:00 |         1321.65 |           718.55 | -0.685779   |          | BUY      |
# | 2019-03-18 00:00:00 |         1350.05 |           710.2  | -1.23566    |          | BUY      |
# | 2019-03-19 00:00:00 |         1376.55 |           722.25 | -1.13937    |          | BUY      |
# | 2019-03-20 00:00:00 |         1375.45 |           738.95 | -0.316214   |          | BUY      |
# | 2019-03-22 00:00:00 |         1341.75 |           743.1  |  0.980812   |          | TP       |
# | 2019-03-25 00:00:00 |         1324.45 |           735.25 |  1.39714    |          |          |
# | 2019-03-26 00:00:00 |         1367.25 |           727.75 | -0.425514   |          |          |
# | 2019-03-27 00:00:00 |         1349.25 |           729.7  |  0.47643    |          |          |
# | 2019-03-28 00:00:00 |         1360    |           737.8  |  0.540919   |          |          |
# | 2019-03-29 00:00:00 |         1363.25 |           743.85 |  0.709151   |          |          |
# | 2019-04-01 00:00:00 |         1391.85 |           755.1  |  0.245027   |          |          |
# | 2019-04-02 00:00:00 |         1389.7  |           759.4  |  0.65515    |          |          |
# | 2019-04-03 00:00:00 |         1375.2  |           753.3  |  0.650657   |          |          |
# | 2019-04-04 00:00:00 |         1353.05 |           747.9  |  1.25293    |          |          |
# | 2019-04-05 00:00:00 |         1353.9  |           759.3  |  2.22612    | SELL     | SELL     |
# | 2019-04-08 00:00:00 |         1329.25 |           767.25 |  3.88496    | SELL     | SELL     |
# | 2019-04-09 00:00:00 |         1334.45 |           760.6  |  1.78116    |          | SELL     |
# | 2019-04-10 00:00:00 |         1331.4  |           752.7  |  1.07229    |          | SELL     |
# | 2019-04-11 00:00:00 |         1346.8  |           742.7  | -0.301442   |          | TP       |
# | 2019-04-12 00:00:00 |         1343.1  |           747.75 |  0.0769667  |          |          |
# | 2019-04-15 00:00:00 |         1340.15 |           727.5  | -1.36306    |          |          |
# | 2019-04-16 00:00:00 |         1343.75 |           724.1  | -1.76445    |          |          |
# | 2019-04-18 00:00:00 |         1385.95 |           717.05 | -3.51736    | BUY      | BUY      |
# | 2019-04-22 00:00:00 |         1345.35 |           721.05 | -1.05276    |          | BUY      |
# | 2019-04-23 00:00:00 |         1363.85 |           728.2  | -1.02618    |          | BUY      |
# | 2019-04-24 00:00:00 |         1389.5  |           736.45 | -1.07704    |          | BUY      |
# | 2019-04-25 00:00:00 |         1372.4  |           728.55 | -0.853468   |          | BUY      |
# | 2019-04-26 00:00:00 |         1392.8  |           738    | -0.775659   |          | BUY      |
# | 2019-04-30 00:00:00 |         1392.8  |           751.35 |  0.256268   |          | TP       |
# +---------------------+-----------------+------------------+-------------+----------+----------+

# %% [markdown]
# function for calculating portfolio of returns(equal weighted portfolio)

# %%
def portfolio_returns (st_date,end_date,amount):
    #pair_date = datetime.datetime()
    pair_list = []
    #print(type(start_date))
    for i in range(len(start_date)):
        if st_date==start_date[i]:
            #print(st_date)
            #print(start_date[i])
            pair_date = start_date[i-12]
            #print(pair_date)
    for time in pairs_from_dict:
        if pair_date==time:
            pair_list=pairs_from_dict[time]
    return_list=[]
    final_amount_list = []
    no_pairs=0
    for pair in pair_list:
        no_pairs = no_pairs+1
        net_profit, profit_by_trades, history, final_amount = returns(pair, st_date,end_date,invested_amount)
        return_list.append(net_profit)
        final_amount_list.append(final_amount)
    portfolio_return = sum(return_list)
    total_amount = sum(final_amount_list)
    
    return portfolio_return, total_amount, no_pairs

# %%
st_date = datetime.datetime(2018, 9, 1)
end_date = datetime.datetime(2018, 12, 1)
amount_invested=1000
per_portfolio_return, final_amount, no_pairs  = portfolio_returns (st_date,end_date,amount_invested)

# %%
print(round(per_portfolio_return,2),round((final_amount/(1000*no_pairs)-1)*100,2))
# Out:
# 74.79 6.06
